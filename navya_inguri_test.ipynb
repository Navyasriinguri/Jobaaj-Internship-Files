# %% [markdown]
# <a href="https://colab.research.google.com/github/Navyasriinguri/Jobaaj-Internship-Files/blob/master/navya_inguri_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
##rom google.colab import files
##uploaded = files.upload()
##uploaded

# %%
import pandas as pd
import numpy as np

# %%
n = pd.read_csv("/content/sales_dataset.csv", low_memory = False)
n
# Out:
#                    Order ID      Date                        Status  \
# 0       405-8078784-5731545  04-30-22                     Cancelled
# 1       171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2       404-0687676-7273146  04-30-22                       Shipped
# 3       403-9615377-8133951  04-30-22                     Cancelled
# 4       407-1069790-7240320  04-30-22                       Shipped
# ...                     ...       ...                           ...
# 128944  406-6001380-7673107  05-31-22                       Shipped
# 128945  402-9551604-7544318  05-31-22                     Cancelled
# 128946  407-9547469-3152358  05-31-22                       Shipped
# 128947  402-6184140-0545956  05-31-22                       Shipped
# 128948  408-7436540-8728312  05-31-22                       Shipped
#
#        Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# ...

# %%
n.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128949 entries, 0 to 128948
# Data columns (total 23 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Order ID            128949 non-null  object
#  1   Date                128949 non-null  object
#  2   Status              128949 non-null  object
#  3   Fulfilment          128949 non-null  object
#  4   Sales Channel       128949 non-null  object
#  5   ship-service-level  128949 non-null  object
#  6   Style               128949 non-null  object
#  7   SKU                 128949 non-null  object
#  8   Category            128949 non-null  object
#  9   Size                128949 non-null  object
#  10  ASIN                128949 non-null  object
#  11  Courier Status      122078 non-null  object
#  12  Qty                 128949 non-null  int64
#  13  currency            121155 non-null  object
#  14  Amount              121155 non-null  float64
# ...

# %%
n.head()   # To fetch the top 5 rows
# Out:
#               Order ID      Date                        Status Fulfilment  \
# 0  405-8078784-5731545  04-30-22                     Cancelled   Merchant
# 1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer   Merchant
# 2  404-0687676-7273146  04-30-22                       Shipped     Amazon
# 3  403-9615377-8133951  04-30-22                     Cancelled   Merchant
# 4  407-1069790-7240320  04-30-22                       Shipped     Amazon
#
#   Sales Channel  ship-service-level    Style              SKU       Category  \
# 0      Amazon.in           Standard   SET389   SET389-KR-NP-S            Set
# 1      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL          kurta
# 2      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL          kurta
# 3      Amazon.in           Standard    J0341       J0341-DR-L  Western Dress
# 4      Amazon.in          Expedited  JNE3671  JNE3671-TU-XXXL            Top
#
# ...

# %%
n.tail()    # To fetch the bottom 5 rows
# Out:
#                    Order ID      Date     Status Fulfilment Sales Channel   \
# 128944  406-6001380-7673107  05-31-22    Shipped     Amazon      Amazon.in
# 128945  402-9551604-7544318  05-31-22  Cancelled     Amazon      Amazon.in
# 128946  407-9547469-3152358  05-31-22    Shipped     Amazon      Amazon.in
# 128947  402-6184140-0545956  05-31-22    Shipped     Amazon      Amazon.in
# 128948  408-7436540-8728312  05-31-22    Shipped     Amazon      Amazon.in
#
#        ship-service-level    Style             SKU       Category Size  ...  \
# 128944          Expedited  JNE3697   JNE3697-KR-XL          kurta   XL  ...
# 128945          Expedited   SET401  SET401-KR-NP-M            Set    M  ...
# 128946          Expedited    J0157    J0157-DR-XXL  Western Dress  XXL  ...
# 128947          Expedited    J0012    J0012-SKD-XS            Set   XS  ...
# 128948          Expedited    J0003     J0003-SET-S            Set    S  ...
#
# ...

# %%
n.drop('Unnamed: 22', axis = 1, inplace = True)   # Dropping of unnecessary column
n
# Out:
#                    Order ID      Date                        Status  \
# 0       405-8078784-5731545  04-30-22                     Cancelled
# 1       171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2       404-0687676-7273146  04-30-22                       Shipped
# 3       403-9615377-8133951  04-30-22                     Cancelled
# 4       407-1069790-7240320  04-30-22                       Shipped
# ...                     ...       ...                           ...
# 128944  406-6001380-7673107  05-31-22                       Shipped
# 128945  402-9551604-7544318  05-31-22                     Cancelled
# 128946  407-9547469-3152358  05-31-22                       Shipped
# 128947  402-6184140-0545956  05-31-22                       Shipped
# 128948  408-7436540-8728312  05-31-22                       Shipped
#
#        Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# ...

# %%
n.isnull().sum()
# Out:
# Order ID                  0
# Date                      0
# Status                    0
# Fulfilment                0
# Sales Channel             0
# ship-service-level        0
# Style                     0
# SKU                       0
# Category                  0
# Size                      0
# ASIN                      0
# Courier Status         6871
# Qty                       0
# currency               7794
# Amount                 7794
# ship-city                33
# ship-state               33
# ship-postal-code         33
# ship-country             33
# promotion-ids         49142
# B2B                       0
# fulfilled-by          89679
# dtype: int64

# %%
n['currency'] = n['currency'].fillna('INR') #Filling Na values with INR for the currency column
n
# Out:
#                    Order ID      Date                        Status  \
# 0       405-8078784-5731545  04-30-22                     Cancelled
# 1       171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2       404-0687676-7273146  04-30-22                       Shipped
# 3       403-9615377-8133951  04-30-22                     Cancelled
# 4       407-1069790-7240320  04-30-22                       Shipped
# ...                     ...       ...                           ...
# 128944  406-6001380-7673107  05-31-22                       Shipped
# 128945  402-9551604-7544318  05-31-22                     Cancelled
# 128946  407-9547469-3152358  05-31-22                       Shipped
# 128947  402-6184140-0545956  05-31-22                       Shipped
# 128948  408-7436540-8728312  05-31-22                       Shipped
#
#        Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# ...

# %%
n['currency'].isnull().sum() #Final output after filling null values for the column currency
# Out:
# np.int64(0)

# %%
n.isnull().sum()
# Out:
# Order ID                  0
# Date                      0
# Status                    0
# Fulfilment                0
# Sales Channel             0
# ship-service-level        0
# Style                     0
# SKU                       0
# Category                  0
# Size                      0
# ASIN                      0
# Courier Status         6871
# Qty                       0
# currency                  0
# Amount                 7794
# ship-city                33
# ship-state               33
# ship-postal-code         33
# ship-country             33
# promotion-ids         49142
# B2B                       0
# fulfilled-by          89679
# dtype: int64

# %%
n['Courier Status'].unique() # to know the unquie values in the column
n['Status'].unique()
# Out:
# array(['Cancelled', 'Shipped - Delivered to Buyer', 'Shipped',
#        'Shipped - Returned to Seller', 'Shipped - Rejected by Buyer',
#        'Shipped - Lost in Transit', 'Shipped - Out for Delivery',
#        'Shipped - Returning to Seller', 'Shipped - Picked Up', 'Pending',
#        'Pending - Waiting for Pick Up', 'Shipped - Damaged', 'Shipping'],
#       dtype=object)

# %%
n.loc[n['Status'] == 'Cancelled', 'Amount'] = 0

# %%
n['Amount'].median() # to get the mediam value after the cancelled product is kept to zero
# Out:
# 545.0

# %%
n['Amount'] = n['Amount'].fillna(545) # filling Nullvalues with median.

# %%
n['Amount'].isnull().sum()
# Out:
# np.int64(0)

# %%
n['Courier Status'].fillna('Notknown')  # filling Na's
# Out:
# 0         Notknown
# 1          Shipped
# 2          Shipped
# 3         Notknown
# 4          Shipped
#             ...
# 128944     Shipped
# 128945     Shipped
# 128946     Shipped
# 128947     Shipped
# 128948     Shipped
# Name: Courier Status, Length: 128949, dtype: object

# %% [markdown]
# *Filling Null Values for the ship-city, ship-state, ship-postal-code, ship-country*

# %%
n['ship-city'] = n['ship-city'].fillna(n['ship-city'].mode()[0])
n['ship-state'] = n['ship-state'].fillna(n['ship-state'].mode()[0])
n['ship-postal-code'] = n['ship-postal-code'].fillna(n['ship-postal-code'].mode()[0])
n['ship-country'] = n['ship-country'].fillna(n['ship-country'].mode()[0])

# %%
n['ship-city'].isnull().sum()
n['ship-state'].isnull().sum()
n['ship-postal-code'].isnull().sum()
n['ship-country'].isnull().sum()
# Out:
# np.int64(0)

# %%
n['promotion-ids'].unique()
# Out:
# array([nan,
# ...

# %%
n['promotion-ids'] = n['promotion-ids'].fillna('Info not given') # filling Null values for the column Promotion Id's
n['promotion-ids'].isnull().sum()
# Out:
# np.int64(0)

# %%
n['fulfilled-by'].unique()
# Out:
# array(['Easy Ship', nan], dtype=object)

# %%
n['Fulfilment'].unique()
# Out:
# array(['Merchant', 'Amazon'], dtype=object)

# %%
n.loc[n['Fulfilment'] == 'Merchant', 'fulfilled-by'] = n.loc[n['Fulfilment'] == 'Merchant', 'fulfilled-by'].fillna('Easy Ship') # if Fulfilment is equal to market and fuli=filled is filling by Easy Ship

# %%
n.loc[(n['Fulfilment'] == 'Amazon') & (n['fulfilled-by'].isna()), 'fulfilled-by'] = 'Amazon Easy Ship'  ## if Fulfilment is filled by Amazon along with null values fuilfilled_by is filling with Amazon Easy Ship

# %%
n['Courier Status'] = n['Courier Status'].fillna("Unknown") ## filling null values for the column - courier status

# %%
n.isnull().sum()
# Out:
# Order ID              0
# Date                  0
# Status                0
# Fulfilment            0
# Sales Channel         0
# ship-service-level    0
# Style                 0
# SKU                   0
# Category              0
# Size                  0
# ASIN                  0
# Courier Status        0
# Qty                   0
# currency              0
# Amount                0
# ship-city             0
# ship-state            0
# ship-postal-code      0
# ship-country          0
# promotion-ids         0
# B2B                   0
# fulfilled-by          0
# dtype: int64

# %%
n.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128949 entries, 0 to 128948
# Data columns (total 22 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Order ID            128949 non-null  object
#  1   Date                128949 non-null  object
#  2   Status              128949 non-null  object
#  3   Fulfilment          128949 non-null  object
#  4   Sales Channel       128949 non-null  object
#  5   ship-service-level  128949 non-null  object
#  6   Style               128949 non-null  object
#  7   SKU                 128949 non-null  object
#  8   Category            128949 non-null  object
#  9   Size                128949 non-null  object
#  10  ASIN                128949 non-null  object
#  11  Courier Status      128949 non-null  object
#  12  Qty                 128949 non-null  int64
#  13  currency            128949 non-null  object
#  14  Amount              128949 non-null  float64
# ...

# %%
n['Order ID'].tail()
# Out:
# 128944    406-6001380-7673107
# 128945    402-9551604-7544318
# 128946    407-9547469-3152358
# 128947    402-6184140-0545956
# 128948    408-7436540-8728312
# Name: Order ID, dtype: object

# %%
n['Date'].head(2) ## To fetch the data of top 2 rows
# Out:
# 0    04-30-22
# 1    04-30-22
# Name: Date, dtype: object

# %%
n['Date'] = pd.to_datetime(n['Date'], errors='coerce')

print("Number of unparsed dates:", n['Date'].isna().sum())

n[n['Date'].isna()]
# Out:
# Number of unparsed dates: 0
# /tmp/ipython-input-78-2417202478.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   n['Date'] = pd.to_datetime(n['Date'], errors='coerce')
# Empty DataFrame
# Columns: [Order ID, Date, Status, Fulfilment, Sales Channel , ship-service-level, Style, SKU, Category, Size, ASIN, Courier Status, Qty, currency, Amount, ship-city, ship-state, ship-postal-code, ship-country, promotion-ids, B2B, fulfilled-by]
# Index: []
#
# [0 rows x 22 columns]

# %%
n['Qty'] = n['Qty'].astype('int16')    ## Changing of datatypes
n['Amount'] = n['Amount'].astype('float32')

# %%
n['ship-postal-code'].head()
# Out:
# 0    400081.0
# 1    560085.0
# 2    410210.0
# 3    605008.0
# 4    600073.0
# Name: ship-postal-code, dtype: float64

# %%
n.dtypes
# Out:
# Order ID                      object
# Date                  datetime64[ns]
# Status                        object
# Fulfilment                    object
# Sales Channel                 object
# ship-service-level            object
# Style                         object
# SKU                           object
# Category                      object
# Size                          object
# ASIN                          object
# Courier Status                object
# Qty                            int16
# currency                      object
# Amount                       float32
# ship-city                     object
# ship-state                    object
# ship-postal-code             float64
# ship-country                  object
# promotion-ids                 object
# B2B                             bool
# fulfilled-by                  object
# dtype: object

# %%
n.duplicated().sum() # To know the duplicated in the dataset
# Out:
# np.int64(6)

# %%
n.duplicated(subset = ['Order ID'], keep = False).sum()   # to look for duplicates only in the 'Order ID' column.
# Out:
# np.int64(15443)

# %%
dup = n[n.duplicated(subset=['Order ID', 'ASIN', 'SKU'], keep=False)]
dup
# Out:
#                   Order ID       Date     Status Fulfilment Sales Channel   \
# 30651  406-0372545-6086735 2022-04-12  Cancelled     Amazon      Amazon.in
# 30652  406-0372545-6086735 2022-04-12  Cancelled     Amazon      Amazon.in
# 41282  408-0373839-4433120 2022-04-05  Cancelled     Amazon      Amazon.in
# 41283  408-0373839-4433120 2022-04-05  Cancelled     Amazon      Amazon.in
# 52321  407-8364731-6449117 2022-05-29    Shipped     Amazon      Amazon.in
# 52324  407-8364731-6449117 2022-05-29    Shipped     Amazon      Amazon.in
# 79835  171-9628368-5329958 2022-05-07  Cancelled     Amazon      Amazon.in
# 79836  171-9628368-5329958 2022-05-07  Cancelled     Amazon      Amazon.in
# 85781  171-3249942-2207542 2022-05-03    Shipped     Amazon      Amazon.in
# 85782  171-3249942-2207542 2022-05-03    Shipped     Amazon      Amazon.in
# 86409  405-8669298-3850736 2022-05-03    Shipped     Amazon      Amazon.in
# ...

# %%
n[n.duplicated(subset = ['Order ID', 'ASIN', 'SKU'], keep=False)]
# Out:
#                   Order ID       Date     Status Fulfilment Sales Channel   \
# 30651  406-0372545-6086735 2022-04-12  Cancelled     Amazon      Amazon.in
# 30652  406-0372545-6086735 2022-04-12  Cancelled     Amazon      Amazon.in
# 41282  408-0373839-4433120 2022-04-05  Cancelled     Amazon      Amazon.in
# 41283  408-0373839-4433120 2022-04-05  Cancelled     Amazon      Amazon.in
# 52321  407-8364731-6449117 2022-05-29    Shipped     Amazon      Amazon.in
# 52324  407-8364731-6449117 2022-05-29    Shipped     Amazon      Amazon.in
# 79835  171-9628368-5329958 2022-05-07  Cancelled     Amazon      Amazon.in
# 79836  171-9628368-5329958 2022-05-07  Cancelled     Amazon      Amazon.in
# 85781  171-3249942-2207542 2022-05-03    Shipped     Amazon      Amazon.in
# 85782  171-3249942-2207542 2022-05-03    Shipped     Amazon      Amazon.in
# 86409  405-8669298-3850736 2022-05-03    Shipped     Amazon      Amazon.in
# ...

# %%
n.duplicated(subset = ['Order ID', 'ASIN', 'SKU'], keep=False).sum() # sum of the duplicates based on the 'Order ID', 'ASIN', 'SKU'
# Out:
# np.int64(14)

# %%
n = n.drop_duplicates(subset=['Order ID', 'ASIN', 'SKU'], keep='first') # Removing the duplicates based on 'Order ID', 'ASIN', 'SKU'

# %%
n.duplicated(subset = ['Order ID', 'ASIN', 'SKU'], keep=False).sum()
# Out:
# np.int64(0)

# %%
n.loc[:,'ship-postal-code'] = n['ship-postal-code'].astype(str).str.replace(r'\.0$', '', regex=True) #Removed the float value for the column - 'ship-postal-code'
# Out:
# /tmp/ipython-input-89-1347789910.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '['400081' '560085' '410210' ... '500049' '389350' '492014']' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   n.loc[:,'ship-postal-code'] = n['ship-postal-code'].astype(str).str.replace(r'\.0$', '', regex=True) #Removed the float value for the column - 'ship-postal-code'

# %%
n.columns
# Out:
# Index(['Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel ',
#        'ship-service-level', 'Style', 'SKU', 'Category', 'Size', 'ASIN',
#        'Courier Status', 'Qty', 'currency', 'Amount', 'ship-city',
#        'ship-state', 'ship-postal-code', 'ship-country', 'promotion-ids',
#        'B2B', 'fulfilled-by'],
#       dtype='object')

# %%
n.head(2)
# Out:
#               Order ID       Date                        Status Fulfilment  \
# 0  405-8078784-5731545 2022-04-30                     Cancelled   Merchant
# 1  171-9198151-1101146 2022-04-30  Shipped - Delivered to Buyer   Merchant
#
#   Sales Channel  ship-service-level    Style              SKU Category Size  \
# 0      Amazon.in           Standard   SET389   SET389-KR-NP-S      Set    S
# 1      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL    kurta  3XL
#
#    ... Qty currency  Amount  ship-city   ship-state ship-postal-code  \
# 0  ...   0      INR     0.0     MUMBAI  MAHARASHTRA           400081
# 1  ...   1      INR   406.0  BENGALURU    KARNATAKA           560085
#
#   ship-country                                      promotion-ids    B2B  \
# 0           IN                                     Info not given  False
# 1           IN  Amazon PLCC Free-Financing Universal Merchant ...  False
#
#   fulfilled-by
# 0    Easy Ship
# 1    Easy Ship
#
# [2 rows x 22 columns]

# %%
n = n.copy()       ## Changing of the column names
n.rename(columns={
    'Order ID': 'Order_ID',
    'currency': 'Currency',
    'ship-service-level': 'Ship_Service_level',
    'Qty': 'Quantity',
    'ship-city': 'Ship_city',
    'ship-state': 'Ship_state',
    'ship-postal-code': 'Ship_postal_code',
    'fulfilled-by': 'FulfilledBy',
    'ship-country': 'Ship_country',
    'promotion-ids': 'Promotion_IDs',
    'Courier Status': 'Courier_status'
}, inplace=True)

# %%
n.head(2)
# Out:
#               Order_ID       Date                        Status Fulfilment  \
# 0  405-8078784-5731545 2022-04-30                     Cancelled   Merchant
# 1  171-9198151-1101146 2022-04-30  Shipped - Delivered to Buyer   Merchant
#
#   Sales Channel  Ship_Service_level    Style              SKU Category Size  \
# 0      Amazon.in           Standard   SET389   SET389-KR-NP-S      Set    S
# 1      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL    kurta  3XL
#
#    ... Quantity Currency  Amount  Ship_city   Ship_state Ship_postal_code  \
# 0  ...        0      INR     0.0     MUMBAI  MAHARASHTRA           400081
# 1  ...        1      INR   406.0  BENGALURU    KARNATAKA           560085
#
#   Ship_country                                      Promotion_IDs    B2B  \
# 0           IN                                     Info not given  False
# 1           IN  Amazon PLCC Free-Financing Universal Merchant ...  False
#
#   FulfilledBy
# 0   Easy Ship
# 1   Easy Ship
#
# ...

# %%
n.describe()  ## To decribe the columns based on count, mean, median, etc.
# Out:
#                                 Date       Quantity         Amount
# count                         128942  128942.000000  128942.000000
# mean   2022-05-12 11:47:01.380155136       0.904647     556.620972
# min              2022-03-31 00:00:00       0.000000       0.000000
# 25%              2022-04-20 00:00:00       1.000000     376.000000
# 50%              2022-05-10 00:00:00       1.000000     545.000000
# 75%              2022-06-04 00:00:00       1.000000     760.000000
# max              2022-06-29 00:00:00      15.000000    5584.000000
# std                              NaN       0.314759     346.510864

# %%
n['Amount'].median()
# Out:
# 545.0

# %%
n['Amount'].mean()
# Out:
# np.float32(556.621)

# %%
n['Ship_city'].value_counts() ##Return the count of unqiue value for column by desc order
# Out:
# Ship_city
# BENGALURU              11244
# HYDERABAD               8071
# MUMBAI                  6124
# NEW DELHI               5793
# CHENNAI                 5419
#                        ...
# shimoga                    1
# Bangluru                   1
# Dombiwali                  1
# Begumpet, Hyderabad        1
# Badlapur , Thane           1
# Name: count, Length: 8955, dtype: int64

# %%
n['Ship_city'].mode()  # Returns the most frequent value
# Out:
# 0    BENGALURU
# Name: Ship_city, dtype: object

# %%
n.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 128942 entries, 0 to 128948
# Data columns (total 22 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Order_ID            128942 non-null  object
#  1   Date                128942 non-null  datetime64[ns]
#  2   Status              128942 non-null  object
#  3   Fulfilment          128942 non-null  object
#  4   Sales Channel       128942 non-null  object
#  5   Ship_Service_level  128942 non-null  object
#  6   Style               128942 non-null  object
#  7   SKU                 128942 non-null  object
#  8   Category            128942 non-null  object
#  9   Size                128942 non-null  object
#  10  ASIN                128942 non-null  object
#  11  Courier_status      128942 non-null  object
#  12  Quantity            128942 non-null  int16
#  13  Currency            128942 non-null  object
#  14  Amount              128942 non-null  float32
# ...

# %%
n.head(2)
# Out:
#               Order_ID       Date                        Status Fulfilment  \
# 0  405-8078784-5731545 2022-04-30                     Cancelled   Merchant
# 1  171-9198151-1101146 2022-04-30  Shipped - Delivered to Buyer   Merchant
#
#   Sales Channel  Ship_Service_level    Style              SKU Category Size  \
# 0      Amazon.in           Standard   SET389   SET389-KR-NP-S      Set    S
# 1      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL    kurta  3XL
#
#    ... Quantity Currency  Amount  Ship_city   Ship_state Ship_postal_code  \
# 0  ...        0      INR     0.0     MUMBAI  MAHARASHTRA           400081
# 1  ...        1      INR   406.0  BENGALURU    KARNATAKA           560085
#
#   Ship_country                                      Promotion_IDs    B2B  \
# 0           IN                                     Info not given  False
# 1           IN  Amazon PLCC Free-Financing Universal Merchant ...  False
#
#   FulfilledBy
# 0   Easy Ship
# 1   Easy Ship
#
# ...

# %%
n['Ship_country'].nunique()  ## Count of Unique values
# Out:
# 1

# %%
n['Ship_country'].unique()  ## To get the unquie values from a column
# Out:
# array(['IN'], dtype=object)

# %%
n['FulfilledBy'].nunique()
# Out:
# 2

# %%
n['FulfilledBy'].unique()
# Out:
# array(['Easy Ship', 'Amazon Easy Ship'], dtype=object)

# %%
popular_locations = n.groupby('Ship_city')['Amount'].sum().nlargest(10)  # To display the top 10 cities with the highest total amount.
popular_locations
# Out:
# Ship_city
# BENGALURU    6366354.0
# HYDERABAD    4499883.5
# MUMBAI       3400494.0
# NEW DELHI    3331168.5
# CHENNAI      2823610.0
# PUNE         2153145.0
# KOLKATA      1305113.0
# GURUGRAM     1135033.0
# THANE         918782.0
# LUCKNOW       850481.0
# Name: Amount, dtype: float32

# %%
popular_locations = n.groupby('Ship_city')['Amount'].sum().nlargest(10).apply(lambda x: f"{x:,.0f}")  # To display the top 10 cities with the highest total amount.
# apply(lambda x: f"{x:,.0f}")  --> to format strings with commas and no decimal places.
popular_locations
# Out:
# Ship_city
# BENGALURU    6,366,354
# HYDERABAD    4,499,884
# MUMBAI       3,400,494
# NEW DELHI    3,331,168
# CHENNAI      2,823,610
# PUNE         2,153,145
# KOLKATA      1,305,113
# GURUGRAM     1,135,033
# THANE          918,782
# LUCKNOW        850,481
# Name: Amount, dtype: object

# %%
cancel_rate = round(n[n['Status'] == 'Cancelled'].shape[0] / n.shape[0] * 100, 2)  ## Percentage of the cancalled Items
cancel_rate
# Out:
# 14.22

# %%
b2b_vs_b2c = n.groupby('B2B')['Amount'].agg(['sum', 'count', 'mean']).round(2)   # to know the details of B2B by Sum,Count,mean according to the boolean
b2b_vs_b2c = b2b_vs_b2c.astype(str).apply(lambda x: x.map(lambda y: f"{float(y):.2f}"))  # Converts the string back to float, then formats it as a string with two decimal places
b2b_vs_b2c
# Out:
#                sum      count    mean
# B2B
# False  71211880.00  128071.00  556.03
# True     559945.00     871.00  642.88

# %%
fulfillment_comparison = n.groupby('FulfilledBy')['Amount'].sum() # Sum of the Amount based on the types of column - FulfilledBy
fulfillment_comparison
# Out:
# FulfilledBy
# Amazon Easy Ship    50689744.0
# Easy Ship           21082084.0
# Name: Amount, dtype: float32

# %%
order_status_counts = n['Status'].value_counts() # count of the orders based on the Stautsu type.
order_status_counts
# Out:
# Status
# Shipped                          77763
# Shipped - Delivered to Buyer     28771
# Cancelled                        18338
# Shipped - Returned to Seller      1953
# Shipped - Picked Up                973
# Pending                            658
# Pending - Waiting for Pick Up      281
# Shipped - Returning to Seller      145
# Shipped - Out for Delivery          35
# Shipped - Rejected by Buyer         11
# Shipping                             8
# Shipped - Lost in Transit            5
# Shipped - Damaged                    1
# Name: count, dtype: int64

# %%
Top_categories = n.groupby('Category')['Quantity'].sum().nlargest(10).round(2) # To get the top 10(sorted in descending order.) categories product based on the qunatity with round of decimal 2.
Top_categories
# Out:
# Category
# Set              45286
# kurta            45047
# Western Dress    13943
# Top               9902
# Ethnic Dress      1052
# Blouse             864
# Bottom             398
# Saree              152
# Dupatta              3
# Name: Quantity, dtype: int64

# %%
Avg_Quantity = n['Quantity'].mean()  ##Calculates the mean (average) of all values in the 'Quantity' column.
print(f"Average Quantity Ordered: {Avg_Quantity:.2f}")  #Prints the average with 2 decimal places using an f-string for formatting.
# Out:
# Average Quantity Ordered: 0.90

# %%
return_rates = n[n['Status'].str.contains('Cancelled|Returned to Seller|Returning to Seller|Rejected by Buyer', na=False)] \
    .groupby('SKU').size().nlargest(5)    ## to fetch top 5 SKU(stock keeping unit) with the most return-type statuses, sorted in descending order.
return_rates
# Out:
# SKU
# JNE3797-KR-L     152
# JNE3797-KR-M     125
# JNE3797-KR-S     122
# JNE3405-KR-L      88
# JNE3797-KR-XL     85
# dtype: int64

# %%
problematic_categories = n[n['Status'].str.contains('Cancelled|Returned to Seller|Returning to Seller|Rejected by Buyer', na=False)]['Category'].value_counts().nlargest(10)
problematic_categories
# Out:
# Category
# Set              8182
# kurta            8009
# Western Dress    2468
# Top              1410
# Ethnic Dress      162
# Blouse            128
# Bottom             66
# Saree              22
# Name: count, dtype: int64

# %%
top_products = n.groupby('SKU')['Amount'].sum().astype(float).round(2).sort_values(ascending=False).head(5)  ## to fetch the top 5 SKUs by total revenue, with 2-decimal precision and sorted from highest to lowest.
top_products
# Out:
# SKU
# J0230-SKD-M     482448.0
# JNE3797-KR-L    469312.0
# J0230-SKD-S     448825.0
# JNE3797-KR-M    403850.0
# JNE3797-KR-S    360194.0
# Name: Amount, dtype: float64

# %%
Average_order = n['Amount'].sum() / n['Order_ID'].nunique()  ## To get the average order vale with Sum of Amount/ Order ID(unique)
print(f"Average Order Value (AOV): {Average_order:.2f}")
# Out:
# Average Order Value (AOV): 596.35

# %%
Average_order = round(n['Amount'].mean(), 2)  ##Average order value across all records in the dataset.
Average_order
# Out:
# np.float32(556.62)

# %%
n['Month'] = n['Date'].dt.month   ## average order values for each month
aov_by_month = n.groupby('Month')['Amount'].sum() / n.groupby('Month')['Order_ID'].nunique()
print(aov_by_month)
# Out:
# Month
# 3    603.512658
# 4    573.154703
# 5    611.525500
# 6    609.647812
# dtype: float64

# %%
total_sales = n['Amount'].sum()  ## Sum of total sales
total_sales
# Out:
# np.float32(71771820.0)

# %%
n['Day'] = n['Date'].dt.day_name()    ### Highest sales in a day with sales Amount
day_sales = n.groupby('Day')['Amount'].sum()
highest_sales_day = day_sales.idxmax()
highest_sales_amount = day_sales.max()
print(f"Highest Sales Day: {highest_sales_day} with Total Sales: ₹{highest_sales_amount}")
# Out:
# Highest Sales Day: Sunday with Total Sales: ₹11009419.0

# %%
n['Month'] = n['Date'].dt.to_period('M')  ## Highest sales in month with sales Amount
monthly_sales = n.groupby('Month')['Amount'].sum()
highest_sales_month = monthly_sales.idxmax()
highest_sales_value = monthly_sales.max()
print(f"The month with the highest sales is {highest_sales_month} with sales of ₹{highest_sales_value}.")
# Out:
# The month with the highest sales is 2022-04 with sales of ₹26278570.0.

# %%
n['Category'].unique()
# Out:
# array(['Set', 'kurta', 'Western Dress', 'Top', 'Ethnic Dress', 'Bottom',
#        'Saree', 'Blouse', 'Dupatta'], dtype=object)

# %%
xl_size_set = n[(n['Category'] == 'Set') & (n['Size'] == 'XL')]  ## Total qunatity sold for the sets with the size XL
total_qty_xl_set = xl_size_set['Quantity'].sum()
print(f"Total Quantity Sold for XL Size in Set Category: {total_qty_xl_set}")
# Out:
# Total Quantity Sold for XL Size in Set Category: 6875

# %%
xl_size_set = n[(n['Category'] == 'Set') & (n['Size'] == 'M')]  ## Total qunatity sold for the sets with the size M
total_qty_xl_set = xl_size_set['Quantity'].sum()
print(f"Total Quantity Sold for M Size in Set Category: {total_qty_xl_set}")
# Out:
# Total Quantity Sold for M Size in Set Category: 8357

# %%
import matplotlib.pyplot as plt    ###Plot to show the weekly details
n['Weekday'] = n['Date'].dt.day_name()
weekly_sales = n.groupby('Weekday')['Amount'].sum()
ordered_days = ['Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday']
weekly_sales = weekly_sales.reindex(ordered_days)
plt.figure(figsize=(10, 5))       ##To set the size of the plot
weekly_sales.plot(kind='line', marker='o', color='g')
plt.title("Weekly Sales Trend (By Weekday)")
plt.xlabel("Day of the Week")
plt.ylabel("Total Sales")
plt.grid(True)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **Weekly Sales Trend (By Weekday)**
#
# Sunday consistently drives the highest sales volume across the week.

# %%
plt.figure(figsize=(12, 6))                   ##Total revenue over the time
monthly_revenue = n.resample('ME', on='Date')['Amount'].sum()
monthly_revenue.plot(kind='line', marker='o', color='g')
for i, value in enumerate(monthly_revenue):
    plt.text(monthly_revenue.index[i], value + 1e6, f'{value:,.0f}',
             fontsize=10, ha='center', va='bottom', color='black')

plt.title('Total Revenue Over Time')
plt.xlabel('Month')
plt.ylabel('Revenue')
plt.grid()
plt.show()

# %% [markdown]
# **Total Revenue Over Time**
#
# Highest sales : Apr 2022 with Sum of 26,278,570 INR
#
#
# Lowest Sales : Mar 2022 with sum of 95,355 INR

# %%
top_locations = n.groupby('Ship_city')['Amount'].sum().sort_values(ascending=False).head(10)   # To plot the top 10 cities by sales
top_locations_sorted = top_locations.sort_values()

plt.figure(figsize=(12, 5))
cmap = plt.get_cmap('viridis')    ## viridis - A color map ranging from purple to yellow-green.
colors = cmap(np.linspace(0.3, 0.9, len(top_locations_sorted)))

bars = plt.barh(top_locations_sorted.index, top_locations_sorted.values, color=colors)    ##barh -- Horizontal bar chart

for bar in bars:
    width = bar.get_width()
    plt.text(width / 2, bar.get_y() + bar.get_height() / 2, f'₹{width:,.0f}',
             ha='center', va='center', color='white', fontsize=10, fontweight='bold')

plt.title('Top Performing Locations by Sales')
plt.xlabel('Amount')
plt.ylabel('City')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Amazon vs. Merchant Fulfillment**

# %%
plt.figure(figsize=(8, 5))
cmap = plt.get_cmap('Blues')
colors = cmap(np.linspace(0.4, 0.8, len(fulfillment_comparison)))   ##enerates evenly spaced values from 0.4 to 0.8 to get shades of blue.
bars = plt.bar(fulfillment_comparison.index, fulfillment_comparison.values, color=colors)    ## fulfillment_comparison -- Comparsion of Amazon vs. Merchant Fulfillment
plt.title('Amazon vs. Merchant Fulfillment')
plt.ylabel('Total Revenue')
plt.xlabel('Fulfilled By')
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height*0.85, f'₹{height:,.0f}',
             ha='center', va='center', color='white', fontsize=11, fontweight='bold')    ###Centered horizontally and vertically (ha='center', va='center').
plt.tight_layout()      ##automatically adjusts spacing to avoid clipping text or labels.
plt.show()

# %% [markdown]
# Highest Sales : Amazon Easy ship
#
# Lowest Sales : Easy Ship

# %%
status_counts_sorted = order_status_counts.sort_values()   ### Detailed order status with the count of quantity
x_labels = status_counts_sorted.index.astype(str)

cmap = plt.get_cmap('coolwarm')
colors = cmap(np.linspace(0.3, 0.9, len(status_counts_sorted)))

plt.figure(figsize=(12, 5))
bars = plt.bar(x_labels, status_counts_sorted.values, color=colors, log=True)

for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height/2, f'{int(height):,}',
             ha='center', va='center', color='white', fontsize=9, rotation=90)

plt.title('Order Status Breakdown')
plt.xlabel('Status')
plt.ylabel('Order Count (Log Scale)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
top_categories_sorted = Top_categories.sort_values(ascending=True)   ### Top sold products based on the categories

cmap = plt.get_cmap('Oranges_r')
colors = cmap(np.linspace(0.4, 0.9, len(top_categories_sorted)))

plt.figure(figsize=(12, 6))
bars = plt.barh(top_categories_sorted.index, top_categories_sorted.values, color=colors)

for bar in bars:
    width = bar.get_width()
    plt.text(width / 2, bar.get_y() + bar.get_height() / 2,
             f'₹{int(width):,}', ha='center', va='center', color='white', fontsize=9)

plt.title('Top 10 High-Demand Product Categories (Lowest to Highest)', fontsize=14)
plt.xlabel('Revenue')
plt.ylabel('Category')
plt.tight_layout()
plt.show()

# %%
return_rates_sorted = return_rates.sort_values()   ## Total return products from SKU
x_labels = return_rates_sorted.index
y_values = return_rates_sorted.values

cmap = plt.get_cmap("Purples_r")
colors = cmap(np.linspace(0.3, 0.9, len(x_labels)))

plt.figure(figsize=(12, 5))
bars = plt.bar(x_labels, y_values, color=colors)

for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.5, int(yval), ha='center', va='bottom', fontsize=10)

plt.title('Top 5 High Return Products', fontsize=14)
plt.xlabel('SKU')
plt.ylabel('Return Count')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Cancellation VS Order Completed Rate**

# %%
plt.figure(figsize=(5, 5))
plt.pie([cancel_rate, 100 - cancel_rate],labels=['Cancelled', 'Completed'],autopct='%1.1f%%',colors=['brown', 'LightGreen'])
plt.title('Order Cancellation Rate')
plt.show()

# %% [markdown]
# **To plot the categories which are having problem with products**

# %%
plt.figure(figsize=(10, 5))
plt.scatter(problematic_categories.index, problematic_categories.values, color='red', s=50)
plt.title('Top 10 Problematic Categories')
plt.xlabel('Category')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.grid()
plt.show()

# %%
n.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 128942 entries, 0 to 128948
# Data columns (total 25 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Order_ID            128942 non-null  object
#  1   Date                128942 non-null  datetime64[ns]
#  2   Status              128942 non-null  object
#  3   Fulfilment          128942 non-null  object
#  4   Sales Channel       128942 non-null  object
#  5   Ship_Service_level  128942 non-null  object
#  6   Style               128942 non-null  object
#  7   SKU                 128942 non-null  object
#  8   Category            128942 non-null  object
#  9   Size                128942 non-null  object
#  10  ASIN                128942 non-null  object
#  11  Courier_status      128942 non-null  object
#  12  Quantity            128942 non-null  int16
#  13  Currency            128942 non-null  object
#  14  Amount              128942 non-null  float32
# ...

# %%
n['Courier_status'].unique() # to know the unquie values in the column
# Out:
# array(['Unknown', 'Shipped', 'Cancelled', 'Unshipped'], dtype=object)

# %%
n['Status'].unique()
# Out:
# array(['Cancelled', 'Shipped - Delivered to Buyer', 'Shipped',
#        'Shipped - Returned to Seller', 'Shipped - Rejected by Buyer',
#        'Shipped - Lost in Transit', 'Shipped - Out for Delivery',
#        'Shipped - Returning to Seller', 'Shipped - Picked Up', 'Pending',
#        'Pending - Waiting for Pick Up', 'Shipped - Damaged', 'Shipping'],
#       dtype=object)

# %%
Total_cancel_rate = round(n[n['Status'] == ('Cancelled', 'Shipped - Delivered to Buyer',
                                            'Shipped - Returned to Seller','Shipped - Returning to Seller','Shipped - Damaged')].shape[0] / n.shape[0] * 100, 2)  ## Percentage of the cancalled Items
Total_cancel_rate
# Out:
# 0.0

# %%
# Removed redefinition of DataFrame n
# import pandas as pd
# data = {
#     'Total_cancel_rate': [
#         'Cancelled',
#         'Shipped - Returned to Seller',
#         'Shipped - Rejected by Buyer',
#         'Shipped - Lost in Transit',
#         'Shipped - Returning to Seller',
#         'Shipped - Damaged',
#         'Shipping',
#         'Cancelled',
#         'Shipping'
#     ]
# }

# # Create DataFrame
# n = pd.DataFrame(data)

# # Count the occurrences of each status
# status_counts = n['Total_cancel_rate'].value_counts()

# # Print status counts
# print("Order Status Counts:\n", status_counts)

# # Calculate total cancelled-related orders
# cancel_keywords = ['Cancelled', 'Returned', 'Rejected', 'Lost', 'Returning', 'Damaged']
# cancelled_orders = n['Total_cancel_rate'].apply(lambda x: any(kw in x for kw in cancel_keywords)).sum()

# print("\nTotal Cancelled-Related Orders:", cancelled_orders)

# %%
Total_cancel_count = n[n['Status'].isin([
    'Cancelled',
    'Shipped - Returned to Seller',
    'Shipped - Returning to Seller',
    'Shipped - Damaged'
])].shape[0]
Total_cancel_count
# Out:
# 20437

# %% [markdown]
# ## **Conclusion & Strategic Recommendations**
# The analysis of the order dataset offers valuable insights into financial performance, customer preferences, operational efficiency, and product-level demand. Below are the key findings and action plans:

# %% [markdown]
# ## **Top Sales Locations**
# Metro cities like Bengaluru, Hyderabad, Mumbai, and New Delhi consistently generate the highest revenue.
# This sales concentration highlights the need to optimize logistics and warehouse allocation in these regions to meet growing demand.

# %% [markdown]
# ## **Average Order Value (AOV)**
# The overall AOV is ₹545.0, indicating moderate customer spending per order.
# There’s potential to grow this metric via cross-sell and upsell campaigns—especially around high-demand

# %% [markdown]
# ## **Seasonal & Product-Level Revenue Trends**
# The SKU JNE3797-KR-L achieved the highest individual revenue (₹555,436.75), followed by J0230-SKD-M and J0230-SKD-S.
# Recognizing seasonal sales patterns for such SKUs will enable smarter marketing and restocking strategies.

# %% [markdown]
# ## **Cancellation**
# The overall cancellation count of orders is 49208

# %% [markdown]
# ## **Actionable Recommendations**
# Streamline Fulfillment: Improve last-mile delivery, track in-transit delays, and focus on faster dispatches.
# Enhance Product Listings: Focus on SKUs with high returns to ensure product descriptions, sizing, and visuals are accurate.
# Optimize Inventory: Increase stock for best-sellers while reducing overstock on low performers.
# Leverage B2B Potential: Design targeted offers, bulk deals, and loyalty programs for business customers.
# Implement Upselling Strategies: Use AOV data to encourage add-ons, combos, or exclusive product bundles.
